# %%
import pandas as pd 
import os 
student_data= os.path.join("resources","students_complete.csv")
student_data_df= pd.read_csv(student_data)
# Put the student names in a list.
student_names=student_data_df["student_name"].tolist()
students_to_fix = []
for name in student_names:
    if len(name.split()) >= 3:
        students_to_fix.append(name)
len(students_to_fix)
# Out:
# 1531

# %%
prefixes = []
for name in students_to_fix:
    if len(name.split()[0]) <= 4:
        prefixes.append(name.split()[0])

# %%
suffixes = []
students_to_fix = []
for name in students_to_fix:
    if len(name.split()[-1]) <= 3:
        suffixes.append(name.split()[-1])

# %%
set(prefixes)
# Out:
# {'Adam',
#  'Amy',
#  'Anna',
#  'Anne',
#  'Carl',
#  'Chad',
#  'Cody',
#  'Cory',
#  'Dale',
#  'Dana',
#  'Dawn',
#  'Dr.',
#  'Emma',
#  'Eric',
#  'Erik',
#  'Erin',
#  'Gail',
#  'Gary',
#  'Gina',
#  'Greg',
#  'Ian',
#  'Jill',
#  'Jodi',
#  'Joe',
#  'John',
#  'Jon',
#  'Jose',
#  'Judy',
#  'Kara',
#  'Kari',
#  'Kim',
#  'Kyle',
#  'Leah',
#  'Lisa',
#  'Lori',
#  'Luke',
#  'Lynn',
#  'Marc',
#  'Mark',
#  'Mary',
#  'Mike',
#  'Miss',
#  'Mr.',
#  'Mrs.',
#  'Ms.',
#  'Noah',
#  'Omar',
#  'Paul',
#  'Ruth',
#  'Ryan',
#  'Sara',
#  'Sean',
#  'Seth',
#  'Tara',
#  'Tina',
#  'Todd',
#  'Toni',
#  'Tony',
#  'Troy'}

# %%
set(suffixes)
# Out:
# set()

# %%
# prefixes need to be removed "Mr.","Mrs.","Miss","Dr."
# Strip "Mrs." from the student names
students_to_fix = []
for name in students_to_fix:
    print(name.replace("Mr.","Mrs.","Miss","Dr."))

# %%
#Suffixes need to be removed DDS,PhD,DVM,PhD

# %%
students_to_fix = []
for name in students_to_fix:
    print(name.replace("Mr.",""))

# %%
import pandas as pd 
import os 
student_data= os.path.join("resources","students_complete.csv")
student_data_df= pd.read_csv(student_data)
student_names=student_data_df["student_name"].tolist()
students_to_fix = []
students_to_fix = []
prefixes_suffixes=["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]
for word in prefixes_suffixes:
    student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")
student_data_df.values
# Out:
# <ipython-input-9-1c372cd1c2b9>:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")
# array([[0, 'Paul Bradley', 'M', ..., 'Huang High School', 66, 79],
#        [1, 'Victor Smith', 'M', ..., 'Huang High School', 94, 61],
#        [2, 'Kevin Rodriguez', 'M', ..., 'Huang High School', 90, 60],
#        ...,
#        [39167, 'Rebecca Tanner', 'F', ..., 'Thomas High School', 73, 84],
#        [39168, 'Desiree Kidd', 'F', ..., 'Thomas High School', 99, 90],
#        [39169, 'Carolyn Jackson', 'F', ..., 'Thomas High School', 95, 75]],
#       dtype=object)

# %%
# Put the cleaned students' names in another list.
student_names = student_data_df["student_name"].tolist()
student_names
# Out:
# ['Paul Bradley',
#  'Victor Smith',
#  'Kevin Rodriguez',
#  'Richard Scott',
#  'Bonnie Ray',
#  'Bryan Miranda',
#  'Sheena Carter',
#  'Nicole Baker',
#  'Michael Roth',
#  'Matthew Greene',
#  'Andrew Alexander',
#  'Daniel Cooper',
#  'Brittney Walker',
#  'William Long',
#  'Tammy Hebert',
#  'Jordan Carson',
#  'Donald Zamora',
#  'Kimberly Santiago',
#  'Kevin Stevens',
#  'Brandi Lyons',
#  'Lisa Davis',
#  'Kristen Lopez',
#  'Kimberly Stewart',
#  'Christopher Parker',
#  'Chelsea Griffith',
#  'Cesar Morris',
#  'Melanie Decker',
#  'Tracey Oconnor',
#  'Kelly James',
#  'Nicole Brown',
#  'Bobby Harris',
#  'Brian Fernandez',
#  'Candace Phelps',
#  'Amy Gonzalez',
#  'Steven Green',
#  'Benjamin Carlson',
#  'Kevin Bailey',
#  'Jesse Newton',
#  'Kimberly Mercado',
#  'Gregory Roberts',
#  'Matthew Mayer',
#  'Jennifer Parks',
#  'John Carlson',
#  'Megan Roberts',
#  'Debra Flores',
#  'Heidi Jackson',
#  'Denise Bradford',
#  'Ellen Brown',
#  'Amy Perkins',
# ...

# %%
students_names_cleaned = []
for name in student_names:
    if len(name.split())>=3:
        students_names_cleaned.append(name)
students_names_cleaned.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-9d05205c2a21> in <module>
#       3     if len(name.split())>=3:
#       4         students_names_cleaned.append(name)
# ----> 5 students_names_cleaned.count()
#
# TypeError: count() takes exactly one argument (0 given)

# %%
prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]
student_data_df["student_name"].str.replace()
for word in prefixes_suffixes:
    student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")
student_data_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-a0bc883a3d42> in <module>
#       1 prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]
# ----> 2 student_data_df["student_name"].str.replace()
#       3 for word in prefixes_suffixes:
#       4     student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")
#       5 student_data_df
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in wrapper(self, *args, **kwargs)
#      99                 )
#     100                 raise TypeError(msg)
# --> 101             return func(self, *args, **kwargs)
#     102
#     103         wrapper.__name__ = func_name
#
# TypeError: replace() missing 2 required positional arguments: 'pat' and 'repl'
